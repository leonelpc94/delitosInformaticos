# %%
import pandas as pd
dataframe = pd.read_csv("delitos_informaticos.csv")
#numeroFilas = len(dataframe) 
#print(numeroFilas)
# Out:
# /tmp/ipykernel_15320/2114825755.py:5: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("datasetInfo.csv")

# %%
nombre= dataframe[ dataframe["DEPARTAMENTO_HECHO"]=="Huila"]
print(nombre["DEPARTAMENTO_HECHO"])
# Out:
# 44         Huila
# 57         Huila
# 82         Huila
# 122        Huila
# 139        Huila
#            ...
# 2890301    Huila
# 2890417    Huila
# 2890424    Huila
# 2890447    Huila
# 2890459    Huila
# Name: DEPARTAMENTO_HECHO, Length: 99888, dtype: object

# %%
filtro =  dataframe[dataframe["DEPARTAMENTO_HECHO"]=="Vaupés"]
filtro
# Out:
#         CRIMINALIDAD ES_ARCHIVO ES_PRECLUSIÓN    ESTADO  ETAPA_CASO      LEY  \
# 2432              SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 3797              NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 5153              SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 5277              SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 5315              NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# ...              ...        ...           ...       ...         ...      ...
# 2889188           SI         NO            NO  INACTIVO  INDAGACIÓN  Ley 906
# 2889344           SI         NO            SI  INACTIVO      JUICIO  Ley 906
# 2890116           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
# 2890140           NO         SI            NO  INACTIVO  INDAGACIÓN  Ley 906
# 2890262           SI         NO            NO    ACTIVO  INDAGACIÓN  Ley 906
#
# ...

# %%
data_frame = pb.read_csv("ANIO_DENUNCIA.csv")
filtro_anio2 = data_frame[data_frame["AÑO_DENUNCIA"]<"2024"]
filtro_anio2.to_csv("AÑO_DENUNCIA.csv", index =False)

# %%
filtro_json = dataframe[dataframe["AÑO_DENUNCIA"]>="2020"]
filtro_json.to_json("año_hecho.json",orient='records', lines=True)
